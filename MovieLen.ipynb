# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
from pandas import Dataframe as df

# %%
u_cols = ['user_id', 'age', 'sex', 'occupation', 'zip_code']
r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
m_cols = ['movie_id', 'title', 'release_date', 'video_release_date', 'imdb_url']

# %%
users = pd.read_csv('/Users/abhishekmane/Downloads/ml-100k/u.user', sep='|', names=u_cols) 
ratings = pd.read_csv('/Users/abhishekmane/Downloads/ml-100k/u.data', sep='\t', names=r_cols)
movies = pd.read_csv('/Users/abhishekmane/Downloads/ml-100k/u.item', sep='|', names=m_cols, usecols=range(5),encoding='latin-1')

movie_ratings = pd.merge(movies, ratings)
df = pd.merge(pd.merge(users,ratings),movies)
df.head(10)
# Out:
#    user_id  age sex  occupation zip_code  movie_id  rating  unix_timestamp  \
# 0        1   24   M  technician    85711        61       4       878542420
# 1       13   47   M    educator    29206        61       4       882140552
# 2       18   35   F       other    37212        61       4       880130803
# 3       58   27   M  programmer    52246        61       5       884305271
# 4       59   49   M    educator    08403        61       4       888204597
# 5       60   50   M  healthcare    06472        61       4       883326652
# 6       76   20   M     student    02215        61       4       875028123
# 7       94   26   M     student    71457        61       5       891720761
# 8      144   53   M  programmer    20910        61       3       888106182
# 9      154   25   M     student    53703        61       4       879138657
#
#                         title release_date  video_release_date  \
# 0  Three Colors: White (1994)  01-Jan-1994                 NaN
# 1  Three Colors: White (1994)  01-Jan-1994                 NaN
# 2  Three Colors: White (1994)  01-Jan-1994                 NaN
# 3  Three Colors: White (1994)  01-Jan-1994                 NaN
# 4  Three Colors: White (1994)  01-Jan-1994                 NaN
# 5  Three Colors: White (1994)  01-Jan-1994                 NaN
# 6  Three Colors: White (1994)  01-Jan-1994                 NaN
# 7  Three Colors: White (1994)  01-Jan-1994                 NaN
# 8  Three Colors: White (1994)  01-Jan-1994                 NaN
# 9  Three Colors: White (1994)  01-Jan-1994                 NaN
#
#                                             imdb_url
# 0  http://us.imdb.com/M/title-exact?Trzy%20kolory...
# 1  http://us.imdb.com/M/title-exact?Trzy%20kolory...
# 2  http://us.imdb.com/M/title-exact?Trzy%20kolory...
# 3  http://us.imdb.com/M/title-exact?Trzy%20kolory...
# 4  http://us.imdb.com/M/title-exact?Trzy%20kolory...
# 5  http://us.imdb.com/M/title-exact?Trzy%20kolory...
# 6  http://us.imdb.com/M/title-exact?Trzy%20kolory...
# 7  http://us.imdb.com/M/title-exact?Trzy%20kolory...
# 8  http://us.imdb.com/M/title-exact?Trzy%20kolory...
# 9  http://us.imdb.com/M/title-exact?Trzy%20kolory...

# %% [markdown]
# # Top 10 rated movies

# %%
most_rated=data.groupby("title").size().sort_values(ascending=False)[:10]

# %%
most_rated.plot(kind="bar",title="Top 10 rated movies",label="count")

# %% [markdown]
# # List of movies that received highest number of "5" rating

# %%
movie_stat=df.groupby('title').agg({'rating':[np.size,np.mean]})
movie_stat.sort_values([('rating','mean')],ascending=False).head()
# Out:
#                                                   rating
#                                                     size mean
# title
# They Made Me a Criminal (1939)                         1  5.0
# Marlene Dietrich: Shadow and Light (1996)              1  5.0
# Saint of Fort Washington, The (1993)                   2  5.0
# Someone Else's America (1995)                          1  5.0
# Star Kid (1997)                                        3  5.0
# Great Day in Harlem, A (1994)                          1  5.0
# Aiqing wansui (1994)                                   1  5.0
# Santa with Muscles (1996)                              2  5.0
# Prefontaine (1997)                                     3  5.0
# Entertaining Angels: The Dorothy Day Story (1996)      1  5.0
